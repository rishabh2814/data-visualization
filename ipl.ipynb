# %%
import os                          #it tells the location of files and axis them and also list them
import pandas as pd               #analyse dataset files
import matplotlib.pyplot as plt   #to generate chart and visualize
import numpy as np               #numerical analysis
import seaborn as sns            #to display graphicaly output like graph and chart

# %%
os.listdir('ipldata')
# Out:
# ['matches.csv']

# %%
os.path.exists('ipldata')
# Out:
# True

# %%
os.path.exists('ipldata/matches.csv')
# Out:
# True

# %%
crick_matches = pd.read_csv('ipldata/matches.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1a91f482d859> in <module>
# ----> 1 crick_matches = pd.read_csv('ipldata/matches.csv')
#
# NameError: name 'pd' is not defined

# %%
type(crick_matches)
# Out:
# pandas.core.frame.DataFrame

# %%
crick_matches = pd.read_csv('ipldata/matches.csv',index_col='id')
crick_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 756 entries, 1 to 11415
# Data columns (total 17 columns):
# season             756 non-null int64
# city               749 non-null object
# date               756 non-null object
# team1              756 non-null object
# team2              756 non-null object
# toss_winner        756 non-null object
# toss_decision      756 non-null object
# result             756 non-null object
# dl_applied         756 non-null int64
# winner             752 non-null object
# win_by_runs        756 non-null int64
# win_by_wickets     756 non-null int64
# player_of_match    752 non-null object
# venue              756 non-null object
# umpire1            754 non-null object
# umpire2            754 non-null object
# umpire3            119 non-null object
# dtypes: int64(4), object(13)
# memory usage: 106.3+ KB

# %%
crick_matches.head
# Out:
# <bound method NDFrame.head of        season           city        date                        team1  \
# id
# 1        2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2        2017           Pune  2017-04-06               Mumbai Indians
# 3        2017         Rajkot  2017-04-07                Gujarat Lions
# 4        2017         Indore  2017-04-08       Rising Pune Supergiant
# 5        2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 6        2017      Hyderabad  2017-04-09                Gujarat Lions
# 7        2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 8        2017         Indore  2017-04-10  Royal Challengers Bangalore
# 9        2017           Pune  2017-04-11             Delhi Daredevils
# 10       2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 11       2017        Kolkata  2017-04-13              Kings XI Punjab
# 12       2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# ...

# %%
crick_matches.tail
# Out:
# <bound method NDFrame.tail of        season           city        date                        team1  \
# id
# 1        2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2        2017           Pune  2017-04-06               Mumbai Indians
# 3        2017         Rajkot  2017-04-07                Gujarat Lions
# 4        2017         Indore  2017-04-08       Rising Pune Supergiant
# 5        2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 6        2017      Hyderabad  2017-04-09                Gujarat Lions
# 7        2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 8        2017         Indore  2017-04-10  Royal Challengers Bangalore
# 9        2017           Pune  2017-04-11             Delhi Daredevils
# 10       2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 11       2017        Kolkata  2017-04-13              Kings XI Punjab
# 12       2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# ...

# %%
plt.figure(facecolor='#ededed')
crick_matches['winner'].value_counts().head(10).plot.bar()

# %%
crick_matches.max()
# Out:
# season                           2019
# date                         31/03/19
# team1             Sunrisers Hyderabad
# team2             Sunrisers Hyderabad
# toss_winner       Sunrisers Hyderabad
# toss_decision                   field
# result                            tie
# dl_applied                          1
# win_by_runs                       146
# win_by_wickets                     10
# venue                Wankhede Stadium
# dtype: object

# %%
crick_matches.sort_values(by='toss_winner', ascending=False)
# Out:
#        season        city        date                        team1  \
# id
# 489      2014       Delhi  2014-05-10             Delhi Daredevils
# 7903     2018     Kolkata    14/04/18        Kolkata Knight Riders
# 11310    2019   Hyderabad    06/04/19               Mumbai Indians
# 11152    2019       Delhi    04/04/19               Delhi Capitals
# 635      2016       Delhi  2016-05-27                Gujarat Lions
# 466      2014     Sharjah  2014-04-22              Kings XI Punjab
# 636      2016   Bangalore  2016-05-29          Sunrisers Hyderabad
# 469      2014         NaN  2014-04-25          Sunrisers Hyderabad
# 474      2014     Sharjah  2014-04-27          Sunrisers Hyderabad
# 7897     2018   Hyderabad    09/04/18             Rajasthan Royals
# 7900     2018   Hyderabad    12/04/18               Mumbai Indians
# 564      2015   Hyderabad  2015-05-11          Sunrisers Hyderabad
# 43       2017   Hyderabad  2017-05-06       Rising Pune Supergiant
# ...

# %%
plt.figure(figsize=(12,3))
crick_matches.win_by_runs.plot()

# %%
crick_matches['win_by_wickets'].plot(style='^:',figsize=(10,10))

# %%
crick_matches['winner'].value_counts()
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
sns.countplot(x='win_by_wickets',data=crick_matches)
plt.xticks(rotation=90)
plt.show()

# %%
crick_matches.plot.scatter(x='win_by_runs', y='win_by_wickets')

# %%
sns.scatterplot(x='win_by_runs', y='season',
                data=crick_matches,
                hue='city',
                palette='icefire',)
plt.show()

# %%
cols =['city', 'win_by_wickets', 'winner']
crick_matches[cols].groupby(by='winner').min()
# Out:
#                              win_by_wickets
# winner
# Chennai Super Kings                       0
# Deccan Chargers                           0
# Delhi Capitals                            0
# Delhi Daredevils                          0
# Gujarat Lions                             0
# Kings XI Punjab                           0
# Kochi Tuskers Kerala                      0
# Kolkata Knight Riders                     0
# Mumbai Indians                            0
# Pune Warriors                             0
# Rajasthan Royals                          0
# Rising Pune Supergiant                    0
# Rising Pune Supergiants                   0
# Royal Challengers Bangalore               0
# Sunrisers Hyderabad                       0

# %%
win_filter = (crick_matches['win_by_runs'] <= 10) & (crick_matches['win_by_wickets'] ==0)
crick_matches[win_filter]
# Out:
#        season           city        date                        team1  \
# id
# 19       2017      Hyderabad  2017-04-17          Sunrisers Hyderabad
# 28       2017         Mumbai  2017-04-24       Rising Pune Supergiant
# 34       2017         Rajkot  2017-04-29                Gujarat Lions
# 50       2017         Mumbai  2017-05-11              Kings XI Punjab
# 51       2017          Delhi  2017-05-12             Delhi Daredevils
# 53       2017        Kolkata  2017-05-13               Mumbai Indians
# 55       2017          Delhi  2017-05-14  Royal Challengers Bangalore
# 59       2017      Hyderabad  2017-05-21               Mumbai Indians
# 67       2008        Chennai  2008-04-23          Chennai Super Kings
# 76       2008          Delhi  2008-04-30             Delhi Daredevils
# 81       2008     Chandigarh  2008-05-03              Kings XI Punjab
# 88       2008        Kolkata  2008-05-08        Kolkata Knight Riders
# ...

# %%
name_with_A = crick_matches.team1.str.startswith('p')
crick_matches[name_with_A]
# Out:
# Empty DataFrame
# Columns: [season, city, date, team1, team2, toss_winner, toss_decision, result, dl_applied, winner, win_by_runs, win_by_wickets, player_of_match, venue, umpire1, umpire2, umpire3]
# Index: []
